# %% [markdown]
# # Setting up a committee structure for a new council

# %% [markdown]
# This notebook is designed to process and clean up the committee list. This is an essential step before we start scraping meetings and matching them to the correct committee names.
#
# ---
#
# ### 🧭 Workflow Overview
#
# 1. **Download the raw HTML file**
#    - Go to the council’s meetings page (e.g. *Browse Meetings*).
#    - Save the full HTML of the committee list (often includes both active and historic entries).
#    - https://democracy.kent.gov.uk:9071/ieDocHome.aspx?XXR=0&Year=-1&Page=1&Categories=-14759&EB=F& - example
#
# 2. **Parse the HTML and extract committee entries**
#    - Use BeautifulSoup to extract all `<li>` elements inside the main `<div class="mgList">`.
#    - Extract each committee name and check if the text includes a phrase like `decommissioned DD/MM/YYYY`.
#
# 3. **Build a raw committee dataframe**
#    - For each committee, extract:
#      - `canonical_name` (the visible name)
#      - `committee_id` (slugified name)
#      - `status`: `active` or `inactive` (based on presence of `decommissioned`)
#      - `date_inactivated`: if applicable
#      - `council_code`: e.g. `"kent_cc"`
#      - `aliases`: initially empty list
#
# 4. **Search and alias-mapping**
#    - Define keywords (e.g. `"social care"`, `"children"`) to explore historical committee variants.
#    - Use `search_committees_by_keyword()` to inspect all matching entries.
#    - Use `auto_map_aliases_by_keyword()` to map **inactive** committee names to a **single active** canonical one.
#
# 5. **Manually discard irrelevant committees**
#    - Define terms (e.g. `"forum"`, `"local"`, `"Maidstone"`) for committees that should be removed entirely.
#    - Use `committees_df` and `inactive_committees` to prune out these entries.
#
# 6. **Maintain an alias map**
#    - Store alias relationships in a central `alias_map_df`.
#    - Append to `../data/references/committee_alias_map.csv` for persistence.
#    - Ensure removed committees are no longer in the final list.
#
# 7. **Inject aliases into canonical records**
#    - Populate each active committee’s `aliases` list based on the reverse lookup from `alias_map_df`.
#
# 8. **Save the cleaned, structured output**
#    - Export the final `committees_df` as a JSONL file for downstream use:
#      ```
#      ../data/metadata/committees.jsonl
#      ../data/references/committee_alias_map.csv
#      ```

# %% [markdown]
# ## Use of GPT for quick results
#
# Alternatively, to extract the data quickly we can use Chat GPT. Feed it the save HTML page, with the following prompt.
# Here is a strong, reusable prompt you can adapt:
#
# ⸻
#
# ### 🧾 Prompt: Extract Structured Committee Data from HTML
#
# You are an expert in web scraping and data extraction. You are given a full HTML file from a UK local government Modern.Gov-based website that lists council committees.
#
# Your task is to extract a structured list of all committees and output a clean .jsonl file, where each line is a JSON object matching the following schema:
#
# {
#   "committee_id": "slug-version-of-canonical-name",
#   "canonical_name": "Full human-readable committee name",
#   "status": "active" or "inactive",
#   "date_inactivated": "DD/MM/YYYY" or null,
#   "aliases": [],
#   "council_code": "short-code-of-council"
# }
#
# Extraction Rules:
# 	•	Parse all committee entries under sections such as:
# 	•	Full Council
# 	•	Executive (Cabinet)
# 	•	Committees
# 	•	Advisory Boards
# 	•	Working Groups or Panels
# 	•	For status, set to "inactive" only if the name includes a phrase like "(Ceased DATE)". Otherwise, use "active".
# 	•	Extract the inactivation date if present, and convert it to "DD/MM/YYYY" format.
# 	•	Use this as your slugify function:
# 		def simple_slugify(text):
# 			text = text.lower()
# 			text = text.replace("’", "'")  # Normalize smart apostrophes
# 			text = re.sub(r"'s\b", "s", text)  # Turn possessives into plain 's' (e.g. "Children's" → "childrens")
# 			text = re.sub(r"\bcommittee\b", "", text)  # Remove the word 'committee' anywhere
# 			text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation
# 			text = re.sub(r"\s+", "-", text.strip())  # Replace spaces with hyphens
# 			text = re.sub(r"-+", "-", text)  # Collapse multiple hyphens
# 			return text.strip("-")
# 	•	The aliases field should be an empty list [] for now.
# 	•	Set "council_code" to a fixed short code, e.g. "tunbridge_wells_bc" or "kent_cc".
#
# Output Format:
# 	•	Return the full data as .jsonl (JSON Lines), with one JSON object per line.
# 	•	Make the file downloadable as committees_tunbridge_wells.jsonl.

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup
import os

# Configuration
INPUT_HTML_FILE = "../data/references/Browse Meetings, 0.html"
OUTPUT_JSONL_FILE = "../data/metadata/committees.jsonl"
ALIAS_CSV_PATH = "../data/references/committee_alias_map.csv"
COUNCIL_CODE = "kent_cc"

# Simple slugify fallback
def simple_slugify(text):
    text = text.lower()
    text = text.replace("’", "'")  # Normalize smart apostrophes
    text = re.sub(r"'s\b", "s", text)  # Turn possessives into plain 's' (e.g. "Children's" → "childrens")
    text = re.sub(r"\bcommittee\b", "", text)  # Remove the word 'committee' anywhere
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation
    text = re.sub(r"\s+", "-", text.strip())  # Replace spaces with hyphens
    text = re.sub(r"-+", "-", text)  # Collapse multiple hyphens
    return text.strip("-")

# Load HTML
with open(INPUT_HTML_FILE, "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

committee_div = soup.find("div", class_="mgList")
committee_items = committee_div.find_all("li")

committee_data = []

# Extract committee data
for li in committee_items:
    link = li.find("a")
    if not link:
        continue

    name = link.get_text(strip=True)
    full_text = li.get_text(separator=' ', strip=True)
    match = re.search(r'decommissioned\s+(\d{2}/\d{2}/\d{4})', full_text)

    if match:
        status = "inactive"
        date_inactivated = match.group(1)
    else:
        status = "active"
        date_inactivated = None

    committee_data.append({
        "committee_id": simple_slugify(name),
        "canonical_name": name,
        "status": status,
        "date_inactivated": date_inactivated,
        "aliases": [],
        "council_code": COUNCIL_CODE
    })

# Define a function to search for committees by keyword (case-insensitive)

def search_committees_by_keyword(df, keyword):
    keyword_lower = keyword.lower()
    matches = df[df["canonical_name"].str.lower().str.contains(keyword_lower)].copy()
    return matches[["committee_id", "canonical_name", "status"]].reset_index(drop=True)

def auto_map_aliases_by_keyword(df, keyword):
    global alias_map_df, committees_df

    matches = df[df["canonical_name"].str.lower().str.contains(keyword.lower())].copy()
    active_rows = matches[matches["status"] == "active"]
    inactive_rows = matches[matches["status"] == "inactive"]

    if len(active_rows) != 1:
        print(f"⚠️ Found {len(active_rows)} active committees for keyword '{keyword}'. Please refine your keyword.")
        return

    canonical_id = active_rows.iloc[0]["committee_id"]

    new_aliases = inactive_rows.apply(
        lambda row: {
            "alias_committee_id": row["committee_id"],
            "alias_name": row["canonical_name"],
            "canonical_committee_id": canonical_id
        }, axis=1
    ).tolist()

    # Append to alias map
    alias_map_df = pd.concat([alias_map_df, pd.DataFrame(new_aliases)], ignore_index=True)

    print(f"✅ Added {len(new_aliases)} aliases pointing to '{canonical_id}'.")


# Create dataframe
committees_df = pd.DataFrame(committee_data)
committees_df.head(20)
# Out:
#                                          committee_id  \
# 0                adult-social-care-and-health-cabinet
# 1   adult-social-care-and-public-health-policy-ove...
# 2                           adult-social-care-cabinet
# 3   adult-social-services-policy-overview-and-scru...
# 4                                             appeals
# 5                               ashford-central-forum
# 6                                 ashford-local-board
# 7                           ashford-rural-south-forum
# 8                            ashford-rural-west-forum
# 9                                               audit
# 10  bexley-and-kent-urgent-care-review-joint-healt...
# 11                                         budget-img
# 12                              business-consultation
# 13                                            cabinet
# 14                                   cabinet-scrutiny
# 15                       canterbury-area-member-panel
# 16                             canterbury-local-board
# 17  canterbury-rural-area-member-panel-north-and-s...
# 18                central-ashford-neighbourhood-forum
# 19  children-families-education-learning-and-devel...
#
#                                        canonical_name    status  \
# 0      Adult Social Care and Health Cabinet Committee  inactive
# 1   Adult Social Care and Public Health Policy Ove...  inactive
# 2                 Adult Social Care Cabinet Committee    active
# 3   Adult Social Services Policy Overview and Scru...  inactive
# 4                                   Appeals Committee  inactive
# 5                               Ashford Central Forum  inactive
# 6                                 Ashford Local Board  inactive
# 7                           Ashford Rural South Forum  inactive
# 8                            Ashford Rural West Forum  inactive
# 9                                     Audit Committee  inactive
# 10  Bexley and Kent Urgent Care Review Joint Healt...  inactive
# 11                                         Budget IMG  inactive
# 12                              Business Consultation  inactive
# 13                                            Cabinet    active
# 14                         Cabinet Scrutiny Committee  inactive
# 15                       Canterbury Area Member Panel  inactive
# 16                             Canterbury Local Board  inactive
# 17  Canterbury Rural Area Member Panel - North and...  inactive
# 18                Central Ashford Neighbourhood Forum  inactive
# 19  Children, Families & Education - Learning and ...  inactive
#
#    date_inactivated aliases council_code
# 0        16/05/2017      []      kent_cc
# 1        31/03/2012      []      kent_cc
# 2              None      []      kent_cc
# 3        05/04/2011      []      kent_cc
# 4        31/12/2005      []      kent_cc
# 5        31/10/2010      []      kent_cc
# 6        30/06/2016      []      kent_cc
# 7        28/02/2011      []      kent_cc
# 8        21/06/2011      []      kent_cc
# 9        31/12/2004      []      kent_cc
# 10       29/01/2020      []      kent_cc
# 11       01/01/2008      []      kent_cc
# 12       31/12/2005      []      kent_cc
# 13             None      []      kent_cc
# 14       30/05/2009      []      kent_cc
# 15       30/06/2016      []      kent_cc
# 16       30/11/2010      []      kent_cc
# 17       30/06/2016      []      kent_cc
# 18       31/10/2010      []      kent_cc
# 19       05/04/2011      []      kent_cc

# %%
committees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   committee_id      179 non-null    object
#  1   canonical_name    179 non-null    object
#  2   status            179 non-null    object
#  3   date_inactivated  147 non-null    object
#  4   aliases           179 non-null    object
#  5   council_code      179 non-null    object
# dtypes: object(6)
# memory usage: 8.5+ KB

# %%
# Count active and inactive
num_active = committees_df[committees_df["status"] == "active"].shape[0]
num_inactive = committees_df[committees_df["status"] == "inactive"].shape[0]

print(f"✅ Active committees: {num_active}")
print(f"❌ Inactive committees: {num_inactive}")

# List all active committee names
active_committees = committees_df[committees_df["status"] == "active"]["canonical_name"].tolist()

print("\nList of active committees:")
for name in active_committees:
    print(f" - {name}")
# Out:
# ✅ Active committees: 32
# ❌ Inactive committees: 147
#
# List of active committees:
#  - Adult Social Care Cabinet Committee
#  - Cabinet
#  - Children's, Young People and Education Cabinet Committee
#  - County Council
#  - Electoral and Boundary Review Committee
#  - Environment & Transport Cabinet Committee
#  - Governance and Audit Committee
#  - Growth, Economic Development and Communities Cabinet Committee
#  - Health Overview and Scrutiny Committee
#  - Health Reform and Public Health Cabinet Committee
#  - Kent and Medway NHS Joint Overview and Scrutiny Committee
#  - Kent and Medway Police and Crime Panel
#  - Kent and Medway Police and Crime Panel - Complaints Sub-Committee
#  - Kent Community Safety Partnership
#  - Kent Flood Risk and Water Management Committee
#  - Kent Health and Wellbeing Board
#  - Kent Utilities Engagement Sub-Committee
#  - Member Development Sub-Committee
#  - Pension Fund Committee
#  - Personnel Committee
#  - Personnel Committee - Member Appointment Panel
#  - Planning Applications Committee
#  - Policy and Resources Cabinet Committee
#  - Property Sub-Committee
#  - Regulation Committee
#  - Regulation Committee Appeal Panel (Transport)
#  - Regulation Committee Member Panel
#  - Regulation Committee Mental Health Guardianship Sub-Committee
#  - Scrutiny Committee
#  - Selection and Member Services Committee
#  - Standards Committee
#  - Standards Committee - Hearing Panel

# %%
# List all active committee names
inactive_committees = committees_df[committees_df["status"] == "inactive"]["canonical_name"].tolist()

print("\nList of inactive committees:")
for name in inactive_committees:
    print(f" - {name}")
# Out:
# List of inactive committees:
#  - Adult Social Care and Health Cabinet Committee
#  - Adult Social Care and Public Health Policy Overview and Scrutiny Committee
#  - Adult Social Services Policy Overview and Scrutiny Committee
#  - Appeals Committee
#  - Ashford Central Forum
#  - Ashford Local Board
#  - Ashford Rural South Forum
#  - Ashford Rural West Forum
#  - Audit Committee
#  - Bexley and Kent Urgent Care Review Joint Health Overview and Scrutiny Committee
#  - Budget IMG
#  - Business Consultation
#  - Cabinet Scrutiny Committee
#  - Canterbury Area Member Panel
#  - Canterbury Local Board
#  - Canterbury Rural Area Member Panel - North and South
#  - Central Ashford Neighbourhood Forum
#  - Children, Families & Education - Learning and Development Policy Overview and Scrutiny Committee
#  - Children, Families & Education - Resources and Infrastructure Policy Overview and Scrutiny Committee
#  - Children, Families & Education - Vulnerable Children and Partnerships Policy Overview and Scrutiny Committee
#  - Children, Families and Education Policy Overview Committee
#  - Children, Families and Educational Achievement Portfolio
#  - Children's Champions Board
#  - Children's Social Care and Health Cabinet Committee
#  - Communities Cabinet Committee
#  - Communities Policy Overview and Scrutiny Committee
#  - Corporate Policy Overview and Scrutiny Committee
#  - Customer and Communities Policy Overview and Scrutiny Committee
#  - Customer and Communities POSC (meeting as the Crime and Disorder Committee)
#  - Dartford Local Boards
#  - Dartford West Local Meeting
#  - Deal and Walmer Neighbourhood Forum
#  - District Police Training Centre Local Authority Committee
#  - Dover District Neighbourhood Forums
#  - Dover Local Board
#  - Dover North Neighbourhood Forum
#  - Dover Town Neighbourhood Forum
#  - Dover West Neighbourhood Forum
#  - East Kent (Joint Arrangements) Committee
#  - East Kent (Joint Scrutiny) Committee
#  - Economic Development Cabinet Committee
#  - Education and Young People's Services Cabinet Committee
#  - Education Cabinet Committee
#  - Environment and Regeneration Policy Overview and Sctuiny Committee
#  - Environment, Highways and Waste Cabinet Committee
#  - Environment, Highways and Waste Policy Overview and Scrutiny Committee
#  - Faversham Local Engagement Forum
#  - Folkestone Neighbourhood Forum
#  - FORWARD PLAN
#  - Governance and Audit Committee Trading Activities Sub - Committee
#  - Governor Appointments Panel
#  - Gravesham East Neighbourhood Forum
#  - Gravesham Local Board
#  - Gravesham Neighbourhood Forums
#  - Gravesham Rural Forum
#  - Gypsy and Traveller Advisory Board
#  - Health and Wellbeing Board (Shadow)
#  - Herne Bay Area Member Panel
#  - Highways Advisory Board
#  - Hythe Neighbourhood Forum
#  - IMG - Going Local
#  - IMG - Learning Disabilities
#  - Joint Appointments Committee - Kent Police Authority
#  - KENT & ESSEX SEA FISHERIES
#  - Kent and Medway Joint Health and Wellbeing Board
#  - Kent and Medway Stroke Review Joint Health Overview and Scrutiny Committee
#  - Kent Highways Partnership
#  - Kent Invicta Award Working Group
#  - KENT PARTNERSHIP - S C S-G
#  - Kent Partnership: Safer and Stronger Communities Group
#  - Kent Schools Admission Forum
#  - Kent Schools Admissions Forum
#  - Kent Schools Organisation Committee
#  - Kent Transport Board
#  - Kent Transport Board Meeting
#  - Kent-Wide Admissions Forum
#  - Local Children's Services Partnerships Sub Committee
#  - Local Health and Wellbeing Boards
#  - Maidstone Borough Council
#  - Maidstone Community Engagement
#  - Maintenance Plan Review
#  - Malling Central Board
#  - Member Development IMG
#  - NHS Overview and Scrutiny Committee
#  - Northfleet & Gravesend West Neighbourhood Forum
#  - Policy Overview Co-ordinating Committee
#  - Regeneration and Economic Development Policy Overview and Scrutiny Committee
#  - Remuneration Panel
#  - Royal Tunbridge Wells Town Forum
#  - Sandwich Neighbourhood Forum
#  - School Organisation Advisory Board
#  - Scrutiny Board
#  - Second Homes Monies - Thanet
#  - Select Committee - Accessing Democracy
#  - Select Committee - Affordable Housing
#  - Select Committee - Alcohol Misuse
#  - Select Committee - Apprenticeships
#  - Select Committee - Autistic Spectrum Disorder (ASD)
#  - Select Committee - Bus Transport and Public Subsidy
#  - Select Committee - Carers in Kent
#  - Select Committee - Commissioning
#  - Select Committee - Corporate Parenting
#  - Select Committee - Dementia
#  - Select Committee - Educational Attainment
#  - Select Committee - Energy Security
#  - Select Committee - Extended Services
#  - Select Committee - Flood Risk
#  - Select Committee - Grammar Schools and Social Mobility
#  - Select Committee - Kent's European Relations
#  - Select Committee - Knife Crime in Kent
#  - Select Committee - Loneliness and Social Isolation
#  - Select Committee - Passenger Rail Services in Kent
#  - Select Committee - Provision of Activities for Young People
#  - Select Committee - Pupil Premium
#  - Select Committee - Renewable Energy
#  - Select Committee - Student Journey
#  - Select Committee: Domestic Abuse
#  - SEND Sub-Committee
#  - Sevenoaks Local Board
#  - Sevenoaks Locality Board
#  - Shadow Kent and Medway Police and Crime Panel
#  - Sheppey Local Engagement Forum
#  - Shepway Liaison Meeting
#  - Shepway Local Board
#  - Sittingbourne Local Engagement Forum
#  - Social Care & Community Health POC
#  - Social Care and Public Health Cabinet Committee
#  - Southern Water Draft Business Plan 2010 - 2015 -  Informal Member Group
#  - SPCB
#  - Specialist Children's Services Policy Overview and Scrutiny Committee
#  - Standards (Consideration) Committee
#  - Standards (Review) Sub Committee
#  - Strategic Planning POC
#  - Superannuation Fund Committee - Appeals
#  - Supporting People Commissioning Body
#  - Supporting People In Kent Commissioning Body
#  - Swale Local Engagement Forums
#  - Swale Rural Forum
#  - Tenterden Forum
#  - Thanet Local Board
#  - Tonbridge & Malling Parish Partnership
#  - Tonbridge and Malling Local Board District
#  - Tonbridge Forum
#  - Tunbridge Wells Local Board
#  - Whitstable Area Member Panel
#  - Wilmington Local Meeting
#  - zzz upgrade June 2024

# %% [markdown]
# ## Steps to identify aliases - use this only when doing it for new councils

# %% [markdown]
# ### Look up terms

# %%
### Search terms
search_term = "social care"
search_term = "children"
search_term = "environment"
search_term = "econom"
search_term = "health overview"
search_term = "audit"
search_term = "adult social"
search_term = "appointment"
search_term = "communities"

search_committees_by_keyword(committees_df, search_term )

# %% [markdown]
# #### Remove without creating aliases

# %%
# ✅ COMPLETE REMOVAL WITHOUT ALIAS MAPPING

# Define all search terms to remove
removal_terms = [
    "forum",
    "local",
    "Canterbury",
    "Select Committee - ",
    "Whitstable",
    "Tonbridge",
    "Maidstone",
    "East Kent",
    "Malling",
    "Herne Bay"
]

# Rebuild inactive_committees fresh from current state
inactive_committees = committees_df[committees_df["status"] == "inactive"].copy()

# Collect all matching committee_ids across all search terms
ids_to_drop = set()
for term in removal_terms:
    matches = search_committees_by_keyword(committees_df, term)
    ids_to_drop.update(matches["committee_id"].tolist())

# Apply removal from both dataframes
committees_df = committees_df[~committees_df["committee_id"].isin(ids_to_drop)].reset_index(drop=True)
inactive_committees = inactive_committees[~inactive_committees["committee_id"].isin(ids_to_drop)].reset_index(drop=True)

# %% [markdown]
# #### Remove with aliases

# %%
# We'll store alias mappings in this dataframe structure for now
alias_map_df = pd.DataFrame(columns=["alias_committee_id", "alias_name", "canonical_committee_id"])
auto_map_aliases_by_keyword(committees_df, search_term)

# %%
# Remove any committees from committees_df that were added as aliases
alias_ids_to_remove = set(alias_map_df["alias_committee_id"])
committees_df = committees_df[~committees_df["committee_id"].isin(alias_ids_to_remove)].reset_index(drop=True)

# Optionally, recreate an inactive_committees dataframe if you're tracking those separately
inactive_committees = committees_df[committees_df["status"] == "inactive"].copy()

committees_df

# %%
alias_map_df

# %% [markdown]
# ### Assign aliases

# %%
# ✅ Bulk alias mapping and cleanup cycle

# Define confirmed aliasable search terms
search_terms = [
    "social care",
    "children",
    "environment",
    "econom",
    "health overview",
    "audit",
    "adult social",
    "appointment",
    "communities"
]

# Reset alias map if needed
alias_map_df = pd.DataFrame(columns=["alias_committee_id", "alias_name", "canonical_committee_id"])

# Loop through each term, map aliases, and clean them out of committee list
for term in search_terms:
    matches = committees_df[committees_df["canonical_name"].str.lower().str.contains(term.lower())]
    active_rows = matches[matches["status"] == "active"]
    inactive_rows = matches[matches["status"] == "inactive"]

    if len(active_rows) != 1:
        print(f"⚠️ '{term}': found {len(active_rows)} active matches — skipping.")
        continue

    canonical_id = active_rows.iloc[0]["committee_id"]

    new_aliases = inactive_rows.apply(
        lambda row: {
            "alias_committee_id": row["committee_id"],
            "alias_name": row["canonical_name"],
            "canonical_committee_id": canonical_id
        }, axis=1
    ).tolist()

    alias_map_df = pd.concat([alias_map_df, pd.DataFrame(new_aliases)], ignore_index=True)
    print(f"✅ '{term}': mapped {len(new_aliases)} aliases → {canonical_id}")

# Remove aliases from main committee lists
alias_ids_to_remove = set(alias_map_df["alias_committee_id"])
committees_df = committees_df[~committees_df["committee_id"].isin(alias_ids_to_remove)].reset_index(drop=True)
inactive_committees = committees_df[committees_df["status"] == "inactive"].copy()
# Out:
# ✅ 'social care': mapped 5 aliases → adult-social-care-cabinet
# ✅ 'children': mapped 9 aliases → childrens-young-people-and-education-cabinet
# ✅ 'environment': mapped 3 aliases → environment-transport-cabinet
# ✅ 'econom': mapped 2 aliases → growth-economic-development-and-communities-cabinet
# ✅ 'health overview': mapped 2 aliases → health-overview-and-scrutiny
# ✅ 'audit': mapped 2 aliases → governance-and-audit
# ✅ 'adult social': mapped 3 aliases → adult-social-care-cabinet
# ✅ 'appointment': mapped 2 aliases → personnel-member-appointment-panel
# ✅ 'communities': mapped 5 aliases → growth-economic-development-and-communities-cabinet

# %%
alias_map_df
# Out:
#                                    alias_committee_id  \
# 0                adult-social-care-and-health-cabinet
# 1   adult-social-care-and-public-health-policy-ove...
# 2            childrens-social-care-and-health-cabinet
# 3                    social-care-community-health-poc
# 4               social-care-and-public-health-cabinet
# 5   children-families-education-learning-and-devel...
# 6   children-families-education-resources-and-infr...
# 7   children-families-education-vulnerable-childre...
# 8     children-families-and-education-policy-overview
# 9   children-families-and-educational-achievement-...
# 10                          childrens-champions-board
# 11           childrens-social-care-and-health-cabinet
# 12          local-childrens-services-partnerships-sub
# 13  specialist-childrens-services-policy-overview-...
# 14  environment-and-regeneration-policy-overview-a...
# 15             environment-highways-and-waste-cabinet
# 16  environment-highways-and-waste-policy-overview...
# 17                       economic-development-cabinet
# 18  regeneration-and-economic-development-policy-o...
# 19  bexley-and-kent-urgent-care-review-joint-healt...
# 20  kent-and-medway-stroke-review-joint-health-ove...
# 21                                              audit
# 22        governance-and-audit-trading-activities-sub
# 23               adult-social-care-and-health-cabinet
# 24  adult-social-care-and-public-health-policy-ove...
# 25  adult-social-services-policy-overview-and-scru...
# 26                        governor-appointments-panel
# 27           joint-appointments-kent-police-authority
# 28                                communities-cabinet
# 29           communities-policy-overview-and-scrutiny
# 30  customer-and-communities-policy-overview-and-s...
# 31  customer-and-communities-posc-meeting-as-the-c...
# 32  kent-partnership-safer-and-stronger-communitie...
#
#                                            alias_name  \
# 0      Adult Social Care and Health Cabinet Committee
# 1   Adult Social Care and Public Health Policy Ove...
# 2   Children's Social Care and Health Cabinet Comm...
# 3                  Social Care & Community Health POC
# 4     Social Care and Public Health Cabinet Committee
# 5   Children, Families & Education - Learning and ...
# 6   Children, Families & Education - Resources and...
# 7   Children, Families & Education - Vulnerable Ch...
# 8   Children, Families and Education Policy Overvi...
# 9   Children, Families and Educational Achievement...
# 10                         Children's Champions Board
# 11  Children's Social Care and Health Cabinet Comm...
# 12  Local Children's Services Partnerships Sub Com...
# 13  Specialist Children's Services Policy Overview...
# 14  Environment and Regeneration Policy Overview a...
# 15  Environment, Highways and Waste Cabinet Committee
# 16  Environment, Highways and Waste Policy Overvie...
# 17             Economic Development Cabinet Committee
# 18  Regeneration and Economic Development Policy O...
# 19  Bexley and Kent Urgent Care Review Joint Healt...
# 20  Kent and Medway Stroke Review Joint Health Ove...
# 21                                    Audit Committee
# 22  Governance and Audit Committee Trading Activit...
# 23     Adult Social Care and Health Cabinet Committee
# 24  Adult Social Care and Public Health Policy Ove...
# 25  Adult Social Services Policy Overview and Scru...
# 26                        Governor Appointments Panel
# 27  Joint Appointments Committee - Kent Police Aut...
# 28                      Communities Cabinet Committee
# 29  Communities Policy Overview and Scrutiny Commi...
# 30  Customer and Communities Policy Overview and S...
# 31  Customer and Communities POSC (meeting as the ...
# 32  Kent Partnership: Safer and Stronger Communiti...
#
#                                canonical_committee_id
# 0                           adult-social-care-cabinet
# 1                           adult-social-care-cabinet
# 2                           adult-social-care-cabinet
# 3                           adult-social-care-cabinet
# 4                           adult-social-care-cabinet
# 5        childrens-young-people-and-education-cabinet
# 6        childrens-young-people-and-education-cabinet
# 7        childrens-young-people-and-education-cabinet
# 8        childrens-young-people-and-education-cabinet
# 9        childrens-young-people-and-education-cabinet
# 10       childrens-young-people-and-education-cabinet
# 11       childrens-young-people-and-education-cabinet
# 12       childrens-young-people-and-education-cabinet
# 13       childrens-young-people-and-education-cabinet
# 14                      environment-transport-cabinet
# 15                      environment-transport-cabinet
# 16                      environment-transport-cabinet
# 17  growth-economic-development-and-communities-ca...
# 18  growth-economic-development-and-communities-ca...
# 19                       health-overview-and-scrutiny
# 20                       health-overview-and-scrutiny
# 21                               governance-and-audit
# 22                               governance-and-audit
# 23                          adult-social-care-cabinet
# 24                          adult-social-care-cabinet
# 25                          adult-social-care-cabinet
# 26                 personnel-member-appointment-panel
# 27                 personnel-member-appointment-panel
# 28  growth-economic-development-and-communities-ca...
# 29  growth-economic-development-and-communities-ca...
# 30  growth-economic-development-and-communities-ca...
# 31  growth-economic-development-and-communities-ca...
# 32  growth-economic-development-and-communities-ca...

# %% [markdown]
# ### Save the alias map permanently

# %%
#alias_map_df.to_csv(ALIAS_CSV_PATH, index=False)

# %% [markdown]
# ## Enrich committees_df with backward references

# %%
from collections import defaultdict

# Build a mapping from canonical_id → list of aliases
aliases_by_canonical = defaultdict(list)
for _, row in alias_map_df.iterrows():
    aliases_by_canonical[row["canonical_committee_id"]].append(row["alias_name"])

# Inject aliases into the main committees_df
committees_df["aliases"] = committees_df.apply(
    lambda row: aliases_by_canonical.get(row["committee_id"], []),
    axis=1
)

# %%
import re

# Strip the word "committee" from the committee_id field
committees_df["committee_id"] = committees_df["committee_id"].apply(
    lambda cid: re.sub(r'-committee\b', '', cid)
)
committees_df.head(30)
# Out:
#                                          committee_id  \
# 0                           adult-social-care-cabinet
# 1                                             appeals
# 2                               ashford-central-forum
# 3                                 ashford-local-board
# 4                           ashford-rural-south-forum
# 5                            ashford-rural-west-forum
# 6                                          budget-img
# 7                               business-consultation
# 8                                             cabinet
# 9                                    cabinet-scrutiny
# 10                       canterbury-area-member-panel
# 11                             canterbury-local-board
# 12  canterbury-rural-area-member-panel-north-and-s...
# 13                central-ashford-neighbourhood-forum
# 14       childrens-young-people-and-education-cabinet
# 15             corporate-policy-overview-and-scrutiny
# 16                                     county-council
# 17                              dartford-local-boards
# 18                        dartford-west-local-meeting
# 19                deal-and-walmer-neighbourhood-forum
# 20    district-police-training-centre-local-authority
# 21                dover-district-neighbourhood-forums
# 22                                  dover-local-board
# 23                    dover-north-neighbourhood-forum
# 24                     dover-town-neighbourhood-forum
# 25                     dover-west-neighbourhood-forum
# 26                       east-kent-joint-arrangements
# 27                           east-kent-joint-scrutiny
# 28       education-and-young-peoples-services-cabinet
# 29                                  education-cabinet
#
#                                        canonical_name    status  \
# 0                 Adult Social Care Cabinet Committee    active
# 1                                   Appeals Committee  inactive
# 2                               Ashford Central Forum  inactive
# 3                                 Ashford Local Board  inactive
# 4                           Ashford Rural South Forum  inactive
# 5                            Ashford Rural West Forum  inactive
# 6                                          Budget IMG  inactive
# 7                               Business Consultation  inactive
# 8                                             Cabinet    active
# 9                          Cabinet Scrutiny Committee  inactive
# 10                       Canterbury Area Member Panel  inactive
# 11                             Canterbury Local Board  inactive
# 12  Canterbury Rural Area Member Panel - North and...  inactive
# 13                Central Ashford Neighbourhood Forum  inactive
# 14  Children's, Young People and Education Cabinet...    active
# 15   Corporate Policy Overview and Scrutiny Committee  inactive
# 16                                     County Council    active
# 17                              Dartford Local Boards  inactive
# 18                        Dartford West Local Meeting  inactive
# 19                Deal and Walmer Neighbourhood Forum  inactive
# 20  District Police Training Centre Local Authorit...  inactive
# 21                Dover District Neighbourhood Forums  inactive
# 22                                  Dover Local Board  inactive
# 23                    Dover North Neighbourhood Forum  inactive
# 24                     Dover Town Neighbourhood Forum  inactive
# 25                     Dover West Neighbourhood Forum  inactive
# 26           East Kent (Joint Arrangements) Committee  inactive
# 27               East Kent (Joint Scrutiny) Committee  inactive
# 28  Education and Young People's Services Cabinet ...  inactive
# 29                        Education Cabinet Committee  inactive
#
#    date_inactivated                                            aliases  \
# 0              None  [Adult Social Care and Health Cabinet Committe...
# 1        31/12/2005                                                 []
# 2        31/10/2010                                                 []
# 3        30/06/2016                                                 []
# 4        28/02/2011                                                 []
# 5        21/06/2011                                                 []
# 6        01/01/2008                                                 []
# 7        31/12/2005                                                 []
# 8              None                                                 []
# 9        30/05/2009                                                 []
# 10       30/06/2016                                                 []
# 11       30/11/2010                                                 []
# 12       30/06/2016                                                 []
# 13       31/10/2010                                                 []
# 14             None  [Children, Families & Education - Learning and...
# 15       31/03/2012                                                 []
# 16             None                                                 []
# 17       30/06/2016                                                 []
# 18       30/11/2009                                                 []
# 19       30/06/2016                                                 []
# 20       26/09/1963                                                 []
# 21       30/06/2016                                                 []
# 22       30/09/2006                                                 []
# 23       30/06/2016                                                 []
# 24       30/06/2016                                                 []
# 25       30/06/2016                                                 []
# 26       31/12/2014                                                 []
# 27       22/12/2012                                                 []
# 28       15/05/2017                                                 []
# 29       31/03/2014                                                 []
#
#    council_code
# 0       kent_cc
# 1       kent_cc
# 2       kent_cc
# 3       kent_cc
# 4       kent_cc
# 5       kent_cc
# 6       kent_cc
# 7       kent_cc
# 8       kent_cc
# 9       kent_cc
# 10      kent_cc
# 11      kent_cc
# 12      kent_cc
# 13      kent_cc
# 14      kent_cc
# 15      kent_cc
# 16      kent_cc
# 17      kent_cc
# 18      kent_cc
# 19      kent_cc
# 20      kent_cc
# 21      kent_cc
# 22      kent_cc
# 23      kent_cc
# 24      kent_cc
# 25      kent_cc
# 26      kent_cc
# 27      kent_cc
# 28      kent_cc
# 29      kent_cc

# %%
# Save committees_df to JSONL
#committees_df.to_json(OUTPUT_JSONL_FILE, orient="records", lines=True, force_ascii=False)
OUTPUT_JSONL_FILE
# Out:
# '../data/metadata/committees.jsonl'
